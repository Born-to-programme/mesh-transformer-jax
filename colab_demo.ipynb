# %% [markdown]
# # GPT-J-6B Inference Demo
#
# <a href="http://colab.research.google.com/github/kingoflolz/mesh-transformer-jax/blob/master/colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# This notebook demonstrates how to run the [GPT-J-6B model](https://github.com/kingoflolz/mesh-transformer-jax/#GPT-J-6B). See the link for more details about the model, including evaluation metrics and credits.

# %% [markdown]
# ## Install Dependencies
#
# First we download the model and install some dependencies. This step takes at least 5 minutes (possibly longer depending on server load).
#
# !!! **Make sure you are using a TPU runtime!** !!!

# %%
# !apt install zstd

# the "slim" version contain only bf16 weights and no optimizer parameters, which minimizes bandwidth and memory
# !time wget -c https://the-eye.eu/public/AI/GPT-J-6B/step_383500_slim.tar.zstd

# !time tar -I zstd -xf step_383500_slim.tar.zstd

# !git clone https://github.com/kingoflolz/mesh-transformer-jax.git
# !pip install -r mesh-transformer-jax/requirements.txt

# jax 0.2.12 is required due to a regression with xmap in 0.2.13
# !pip install mesh-transformer-jax/ jax==0.2.12 tensorflow==2.5.0
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 278 kB of archives.
# After this operation, 1,141 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 zstd amd64 1.3.3+dfsg-2ubuntu1.2 [278 kB]
# Fetched 278 kB in 1s (330 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 155676 files and directories currently installed.)
# Preparing to unpack .../zstd_1.3.3+dfsg-2ubuntu1.2_amd64.deb ...
# Unpacking zstd (1.3.3+dfsg-2ubuntu1.2) ...
# Setting up zstd (1.3.3+dfsg-2ubuntu1.2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# --2022-08-23 12:05:11--  https://the-eye.eu/public/AI/GPT-J-6B/step_383500_slim.tar.zstd
# Resolving the-eye.eu (the-eye.eu)... 162.213.130.6
# Connecting to the-eye.eu (the-eye.eu)|162.213.130.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9414712325 (8.8G) [application/octet-stream]
# Saving to: ‘step_383500_slim.tar.zstd’
#
# step_383500_slim.ta 100%[===================>]   8.77G  72.3MB/s    in 2m 10s
#
# 2022-08-23 12:07:22 (68.9 MB/s) - ‘step_383500_slim.tar.zstd’ saved [9414712325/9414712325]
#
#
# real	2m10.641s
# user	0m7.644s
# sys	0m34.455s
#
# real	1m43.317s
# user	0m40.679s
# sys	0m39.123s
# Cloning into 'mesh-transformer-jax'...
# remote: Enumerating objects: 791, done.
# remote: Total 791 (delta 0), reused 0 (delta 0), pack-reused 791
# Receiving objects: 100% (791/791), 320.03 KiB | 3.23 MiB/s, done.
# Resolving deltas: 100% (486/486), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness/ (from -r mesh-transformer-jax/requirements.txt (line 9))
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness/ to /tmp/pip-req-build-z2ucjs62
#   Running command git clone -q https://github.com/EleutherAI/lm-evaluation-harness/ /tmp/pip-req-build-z2ucjs62
# Collecting numpy~=1.19.5
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 5.1 MB/s
# Requirement already satisfied: tqdm>=4.45.0 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 2)) (4.64.0)
# Collecting wandb>=0.11.2
#   Downloading wandb-0.13.2-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 24.3 MB/s
# Collecting einops~=0.3.0
#   Downloading einops-0.3.2-py3-none-any.whl (25 kB)
# Collecting requests~=2.25.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 7.8 MB/s
# Collecting fabric~=2.6.0
#   Downloading fabric-2.6.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.6 MB/s
# Collecting optax==0.0.9
#   Downloading optax-0.0.9-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 61.3 MB/s
# Collecting dm-haiku==0.0.5
#   Downloading dm_haiku-0.0.5-py3-none-any.whl (287 kB)
#      |████████████████████████████████| 287 kB 58.0 MB/s
# Collecting ray[default]==1.4.1
#   Downloading ray-1.4.1-cp37-cp37m-manylinux2014_x86_64.whl (51.6 MB)
#      |████████████████████████████████| 51.6 MB 1.2 MB/s
# Collecting jax~=0.2.12
#   Downloading jax-0.2.28.tar.gz (887 kB)
#      |████████████████████████████████| 887 kB 38.1 MB/s
# Requirement already satisfied: Flask~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 12)) (1.1.4)
# Collecting cloudpickle~=1.3.0
#   Downloading cloudpickle-1.3.0-py2.py3-none-any.whl (26 kB)
# Collecting tensorflow-cpu~=2.6.0
#   Downloading tensorflow_cpu-2.6.5-cp37-cp37m-manylinux2010_x86_64.whl (178.2 MB)
#      |████████████████████████████████| 178.2 MB 47 kB/s
# Collecting google-cloud-storage~=1.36.2
#   Downloading google_cloud_storage-1.36.2-py2.py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 5.7 MB/s
# Collecting transformers
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 42.7 MB/s
# Requirement already satisfied: smart_open[gcs] in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 17)) (5.2.1)
# Collecting func_timeout
#   Downloading func_timeout-4.3.5.tar.gz (44 kB)
#      |████████████████████████████████| 44 kB 2.2 MB/s
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.6 MB/s
# Collecting fastapi
#   Downloading fastapi-0.79.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.0 MB/s
# Collecting uvicorn
#   Downloading uvicorn-0.18.2-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 4.7 MB/s
# Collecting lm_dataformat
#   Downloading lm_dataformat-0.0.20-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: pathy in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 23)) (0.6.2)
# Collecting bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt
#   Downloading https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip
#      / 16.5 MB 98 kB/s
# Collecting datasets>=2.0.0
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 52.4 MB/s
# Requirement already satisfied: click>=7.1 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (7.1.2)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.0.2)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.12.1+cu113)
# Collecting sqlitedict==1.6.0
#   Downloading sqlitedict-1.6.0.tar.gz (29 kB)
# Collecting pytablewriter==0.58.0
#   Downloading pytablewriter-0.58.0-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 5.4 MB/s
# Collecting sacrebleu==1.5.0
#   Downloading sacrebleu-1.5.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.5 MB/s
# Collecting rouge-score==0.0.4
#   Downloading rouge_score-0.0.4-py2.py3-none-any.whl (22 kB)
# Collecting pycountry==20.7.3
#   Downloading pycountry-20.7.3.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 36.8 MB/s
# Collecting numexpr==2.7.2
#   Downloading numexpr-2.7.2-cp37-cp37m-manylinux2010_x86_64.whl (471 kB)
#      |████████████████████████████████| 471 kB 51.8 MB/s
# Collecting pybind11==2.6.2
#   Downloading pybind11-2.6.2-py2.py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 58.2 MB/s
# Collecting tqdm-multiprocess==0.0.11
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Collecting zstandard==0.15.2
#   Downloading zstandard-0.15.2-cp37-cp37m-manylinux2014_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 44.3 MB/s
# Collecting jsonlines==2.0.0
#   Downloading jsonlines-2.0.0-py3-none-any.whl (6.3 kB)
# Collecting mock==4.0.3
#   Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Collecting openai==0.6.4
#   Downloading openai-0.6.4.tar.gz (159 kB)
#      |████████████████████████████████| 159 kB 44.4 MB/s
# Requirement already satisfied: jieba==0.42.1 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.42.1)
# Collecting nagisa==0.2.7
#   Downloading nagisa-0.2.7-cp37-cp37m-manylinux1_x86_64.whl (21.5 MB)
#      |████████████████████████████████| 21.5 MB 1.2 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.7.3)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.8.2+zzzcolab20220719082949)
# Collecting tf-slim>=1.1
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 57.5 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 50.1 MB/s
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.7/dist-packages (from optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.3.14+cuda11.cudnn805)
# Collecting chex>=0.0.4
#   Downloading chex-0.1.4-py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 4.8 MB/s
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (1.2.0)
# Collecting jmp>=0.0.2
#   Downloading jmp-0.0.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from dm-haiku==0.0.5->-r mesh-transformer-jax/requirements.txt (line 8)) (0.8.10)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from dm-haiku==0.0.5->-r mesh-transformer-jax/requirements.txt (line 8)) (4.1.1)
# Requirement already satisfied: ujson in /usr/local/lib/python3.7/dist-packages (from lm_dataformat->-r mesh-transformer-jax/requirements.txt (line 22)) (5.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nagisa==0.2.7->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.15.0)
# Collecting DyNet
#   Downloading dyNET-2.1.2-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 41.1 MB/s
# Collecting typepy[datetime]<2,>=1.1.1
#   Downloading typepy-1.3.0-py3-none-any.whl (31 kB)
# Collecting DataProperty<2,>=0.50.0
#   Downloading DataProperty-0.55.0-py3-none-any.whl (26 kB)
# Collecting pathvalidate<3,>=2.3.0
#   Downloading pathvalidate-2.5.2-py3-none-any.whl (20 kB)
# Collecting tabledata<2,>=1.1.3
#   Downloading tabledata-1.3.0-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5
#   Downloading tcolorpy-0.1.2-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.7/dist-packages (from pytablewriter==0.58.0->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (57.4.0)
# Collecting mbstrdecoder<2,>=1.0.0
#   Downloading mbstrdecoder-1.1.1-py3-none-any.whl (7.7 kB)
# Collecting msgfy<1,>=0.1.0
#   Downloading msgfy-0.2.0-py3-none-any.whl (4.3 kB)
# Collecting redis>=3.5.0
#   Downloading redis-4.3.4-py3-none-any.whl (246 kB)
#      |████████████████████████████████| 246 kB 61.6 MB/s
# Collecting aioredis
#   Downloading aioredis-2.0.1-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 8.3 MB/s
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (6.0)
# Collecting prometheus-client>=0.7.1
#   Downloading prometheus_client-0.14.1-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.7 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (3.8.1)
# Collecting opencensus
#   Downloading opencensus-0.11.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 67.1 MB/s
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.12-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 53.5 MB/s
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (4.3.3)
# Requirement already satisfied: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (3.17.3)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.47.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (3.8.0)
# Requirement already satisfied: pydantic>=1.8 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.9.2)
# Collecting gpustat
#   Downloading gpustat-0.6.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 6.1 MB/s
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Collecting colorful
#   Downloading colorful-0.5.4-py2.py3-none-any.whl (201 kB)
#      |████████████████████████████████| 201 kB 39.1 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from rouge-score==0.0.4->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.7)
# Collecting portalocker
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 64.6 MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (2.3)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 63.4 MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (5.4.8)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (2.10)
# Collecting invoke<2.0,>=1.3
#   Downloading invoke-1.7.1-py3-none-any.whl (215 kB)
#      |████████████████████████████████| 215 kB 42.5 MB/s
# Collecting paramiko>=2.4
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
#      |████████████████████████████████| 212 kB 51.9 MB/s
# Collecting pathlib2
#   Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.7/dist-packages (from jax~=0.2.12->-r mesh-transformer-jax/requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (1.0.1)
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 66.2 MB/s
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.1.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.6.3)
# Collecting typing-extensions
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting keras<2.7,>=2.6.0
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 48.3 MB/s
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting tensorboard<2.7,>=2.6.0
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 36.2 MB/s
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.1.2)
# Collecting absl-py>=0.7.1
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 52.0 MB/s
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.1.0)
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.37.1)
# Collecting google-resumable-media<2.0dev,>=1.2.0
#   Downloading google_resumable_media-1.3.3-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.3 MB/s
# Requirement already satisfied: google-auth<2.0dev,>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.35.0)
# Collecting google-cloud-core<2.0dev,>=1.4.1
#   Downloading google_cloud_core-1.7.3-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 9.8 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (4.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 40.7 MB/s
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.7/dist-packages (from chex>=0.0.4->optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.1.7)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from chex>=0.0.4->optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets>=2.0.0->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.3.5.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 56.0 MB/s
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=2.0.0->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (6.0.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 65.5 MB/s
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets>=2.0.0->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2022.7.1)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.5 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (4.2.4)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.31.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.56.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (2022.2.1)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.3.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38 kB)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.5.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (3.0.9)
# Collecting cryptography>=2.5
#   Downloading cryptography-37.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 43.2 MB/s
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      |████████████████████████████████| 856 kB 58.4 MB/s
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.2-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (62 kB)
#      |████████████████████████████████| 62 kB 869 kB/s
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (2.21)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (0.4.8)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (4.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (3.8.1)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 40.4 MB/s
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.4.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.2.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from typepy[datetime]<2,>=1.1.1->pytablewriter==0.58.0->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.8.2)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->-r mesh-transformer-jax/requirements.txt (line 19)) (0.2.5)
# Collecting starlette==0.19.1
#   Downloading starlette-0.19.1-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 7.9 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting h11>=0.8
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.9 MB/s
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from pathy->-r mesh-transformer-jax/requirements.txt (line 23)) (0.4.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (22.1.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.13.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (2.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from DyNet->nagisa==0.2.7->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.29.32)
# Collecting nvidia-ml-py3>=7.352.0
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
# Collecting blessings>=1.6
#   Downloading blessings-1.7-py3-none-any.whl (18 kB)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.18.1)
# Collecting opencensus-context>=0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting tensorflow
#   Downloading tensorflow-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      |████████████████████████████████| 511.7 MB 5.6 kB/s
#   Downloading tensorflow-2.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      |████████████████████████████████| 511.7 MB 4.6 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.2%2Bzzzcolab20220822160911-cp37-cp37m-linux_x86_64.whl (437.8 MB)
#      |████████████████████████████████| 437.8 MB 23 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.2%2Bzzzcolab20220714162028-cp37-cp37m-linux_x86_64.whl (518.1 MB)
#      |████████████████████████████████| 518.1 MB 19 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.2%2Bzzzcolab20220714152931-cp37-cp37m-linux_x86_64.whl (587.9 MB)
#      |████████████████████████████████| 587.9 MB 12 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.2%2Bzzzcolab20220629235552-cp37-cp37m-linux_x86_64.whl (668.6 MB)
#      |████████████████████████████████| 668.6 MB 7.1 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.2%2Bzzzcolab20220527125636-cp37-cp37m-linux_x86_64.whl (668.6 MB)
#      |████████████████████████████████| 668.6 MB 1.6 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.2%2Bzzzcolab20220523105045-cp37-cp37m-linux_x86_64.whl (668.6 MB)
#      |████████████████████████████████| 668.6 MB 2.5 kB/s
#   Downloading tensorflow-2.8.2-cp37-cp37m-manylinux2010_x86_64.whl (497.9 MB)
#      |████████████████████████████████| 497.9 MB 14 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.1%2Bzzzcolab20220518083849-cp37-cp37m-linux_x86_64.whl (668.6 MB)
#      |████████████████████████████████| 668.6 MB 6.8 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.1%2Bzzzcolab20220516111314-cp37-cp37m-linux_x86_64.whl (668.6 MB)
#      |████████████████████████████████| 668.6 MB 16 kB/s
#   Downloading tensorflow-2.8.1-cp37-cp37m-manylinux2010_x86_64.whl (497.9 MB)
#      |████████████████████████████████| 497.9 MB 17 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.8.0%2Bzzzcolab20220506162203-cp37-cp37m-linux_x86_64.whl (668.3 MB)
#      |████████████████████████████████| 668.3 MB 18 kB/s
#   Downloading tensorflow-2.8.0-cp37-cp37m-manylinux2010_x86_64.whl (497.5 MB)
#      |████████████████████████████████| 497.5 MB 25 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.7.3%2Bzzzcolab20220523111007-cp37-cp37m-linux_x86_64.whl (671.4 MB)
#      |████████████████████████████████| 671.4 MB 15 kB/s
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt->lm-eval==0.2.0->-r mesh-transformer-jax/requirements.txt (line 9)) (14.0.6)
#   Downloading tensorflow-2.7.3-cp37-cp37m-manylinux2010_x86_64.whl (495.4 MB)
#      |████████████████████████████████| 495.4 MB 31 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.7.2%2Bzzzcolab20220516114640-cp37-cp37m-linux_x86_64.whl (671.4 MB)
#      |████████████████████████████████| 671.4 MB 1.8 kB/s
#   Downloading tensorflow-2.7.2-cp37-cp37m-manylinux2010_x86_64.whl (495.4 MB)
#      |████████████████████████████████| 495.4 MB 29 kB/s
#   Downloading tensorflow-2.7.1-cp37-cp37m-manylinux2010_x86_64.whl (495.0 MB)
#      |████████████████████████████████| 495.0 MB 32 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.7.0%2Bzzzcolab20220506150900-cp37-cp37m-linux_x86_64.whl (665.5 MB)
#      |████████████████████████████████| 665.5 MB 24 kB/s
#   Downloading tensorflow-2.7.0-cp37-cp37m-manylinux2010_x86_64.whl (489.6 MB)
#      |████████████████████████████████| 489.6 MB 26 kB/s
#   Downloading https://us-python.pkg.dev/colab-wheels/public/tensorflow/tensorflow-2.6.5%2Bzzzcolab20220523104206-cp37-cp37m-linux_x86_64.whl (570.3 MB)
#      |████████████████████████████████| 570.3 MB 341 bytes/s
# Building wheels for collected packages: lm-eval, bleurt, openai, pycountry, sqlitedict, jax, clang, wrapt, func-timeout, gpustat, nvidia-ml-py3, pathtools
#   Building wheel for lm-eval (setup.py) ... done
#   Created wheel for lm-eval: filename=lm_eval-0.2.0-py3-none-any.whl size=186616 sha256=55019b80d510f190b1040acea1d96fee080b13403d76acb3d4aef138bc670ba2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-blxj0wts/wheels/35/22/ec/71da337686fde904ec27f675d1bf73c4f253c48a6174d822b0
#   Building wheel for bleurt (setup.py) ... done
#   Created wheel for bleurt: filename=BLEURT-0.0.2-py3-none-any.whl size=16454023 sha256=1032841dacac9a03b0b5f969d4264b3eee16e22619a34fdc7a288b1f7b4c05b5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-blxj0wts/wheels/e4/25/b5/d3b124fc2717a794a8dcb176fac9a01bec46e9f3ff0dbf5d37
#   Building wheel for openai (setup.py) ... done
#   Created wheel for openai: filename=openai-0.6.4-py3-none-any.whl size=172215 sha256=b6bf8d4a062acc6040adaa14da6c91a4dd3dc81a7c891031f9674e916c760914
#   Stored in directory: /root/.cache/pip/wheels/54/c4/02/aa519fe2aaf97a9bba197a8585182c8c07802760351afdb64a
#   Building wheel for pycountry (setup.py) ... done
#   Created wheel for pycountry: filename=pycountry-20.7.3-py2.py3-none-any.whl size=10746882 sha256=a2604f381ae994f3896cfd862259b25406d16b207eaa8ca1cd30630c30d6c976
#   Stored in directory: /root/.cache/pip/wheels/57/e8/3f/120ccc1ff7541c108bc5d656e2a14c39da0d824653b62284c6
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-1.6.0-py3-none-any.whl size=14712 sha256=89b8e8f0a465112e7153fb98a2efbe74ce13b65be563a0c69cf848287d3e391b
#   Stored in directory: /root/.cache/pip/wheels/58/dd/2c/0a57aadf6a7f26bec0af66d742c50af74d11967780f0bb7a7d
#   Building wheel for jax (setup.py) ... done
#   Created wheel for jax: filename=jax-0.2.28-py3-none-any.whl size=1028669 sha256=770cd2bbbd0b69d17eb89a1ed3eae26c69e8d88328c60e36d8db610e840f9925
#   Stored in directory: /root/.cache/pip/wheels/e2/60/4c/0cf931b766116b73950d9b6fca5813a45789d45d412a8d7272
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30694 sha256=155fe988961b244dcde87b0801f2e55bf92cc278012a7e40f8ab715eee0cb991
#   Stored in directory: /root/.cache/pip/wheels/98/91/04/971b4c587cf47ae952b108949b46926f426c02832d120a082a
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68720 sha256=afb85850e8890e10337dfee884d80aa1e1545f4724ef1592a754bc144c8a8adf
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
#   Building wheel for func-timeout (setup.py) ... done
#   Created wheel for func-timeout: filename=func_timeout-4.3.5-py3-none-any.whl size=15098 sha256=ec125d82a1a86c7707fd4b5cf9bf9a53cb601b59f480e06d5f4c7f348c46bb45
#   Stored in directory: /root/.cache/pip/wheels/68/b5/a5/67c4364c354e141f5a1bd3ec568126f77877ab7554cf5af8cb
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-py3-none-any.whl size=12617 sha256=2853773300db4c591ba964b03c062b0805f55513279eac28412466756e4de432
#   Stored in directory: /root/.cache/pip/wheels/e6/67/af/f1ad15974b8fd95f59a63dbf854483ebe5c7a46a93930798b8
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19190 sha256=4258b1a21893accb095438b4b01a892a11863c6838f4f8fcd701ad3a45db2f69
#   Stored in directory: /root/.cache/pip/wheels/df/99/da/c34f202dc8fd1dffd35e0ecf1a7d7f8374ca05fbcbaf974b83
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=2ac41c9025643b1f545ea6c97b110102eb956abd16a650d47e45c403468f0ab6
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built lm-eval bleurt openai pycountry sqlitedict jax clang wrapt func-timeout gpustat nvidia-ml-py3 pathtools
# Installing collected packages: urllib3, typing-extensions, requests, mbstrdecoder, typepy, wrapt, numpy, absl-py, tensorflow-estimator, tensorboard, sniffio, smmap, opencensus-context, nvidia-ml-py3, keras, google-crc32c, gast, flatbuffers, deprecated, DataProperty, clang, blessings, zstandard, xxhash, tokenizers, tf-slim, tensorflow, tcolorpy, tabledata, sentencepiece, responses, redis, pynacl, py-spy, prometheus-client, portalocker, pathvalidate, opencensus, multiprocess, msgfy, jsonlines, jax, huggingface-hub, gpustat, google-resumable-media, google-cloud-core, gitdb, DyNet, cryptography, colorama, bcrypt, anyio, aioredis, aiohttp-cors, transformers, tqdm-multiprocess, starlette, sqlitedict, shortuuid, setproctitle, sentry-sdk, sacrebleu, rouge-score, ray, pytablewriter, pycountry, pybind11, pathtools, pathlib2, paramiko, openai, numexpr, nagisa, mock, lm-dataformat, jmp, invoke, h11, google-cloud-storage, GitPython, docker-pycreds, datasets, colorful, chex, bleurt, wandb, uvicorn, tensorflow-cpu, optax, lm-eval, func-timeout, ftfy, fastapi, fabric, einops, dm-haiku, cloudpickle
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.2.0
#     Uninstalling absl-py-1.2.0:
#       Successfully uninstalled absl-py-1.2.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220719082949
#     Uninstalling tensorflow-2.8.2+zzzcolab20220719082949:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220719082949
#   Attempting uninstall: jax
#     Found existing installation: jax 0.3.14
#     Uninstalling jax-0.3.14:
#       Successfully uninstalled jax-0.3.14
#   Attempting uninstall: google-resumable-media
#     Found existing installation: google-resumable-media 0.4.1
#     Uninstalling google-resumable-media-0.4.1:
#       Successfully uninstalled google-resumable-media-0.4.1
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 1.0.3
#     Uninstalling google-cloud-core-1.0.3:
#       Successfully uninstalled google-cloud-core-1.0.3
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.8.3
#     Uninstalling numexpr-2.8.3:
#       Successfully uninstalled numexpr-2.8.3
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 1.18.1
#     Uninstalling google-cloud-storage-1.18.1:
#       Successfully uninstalled google-cloud-storage-1.18.1
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.5.0
#     Uninstalling cloudpickle-1.5.0:
#       Successfully uninstalled cloudpickle-1.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
# google-cloud-bigquery 1.21.0 requires google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1, but you have google-resumable-media 1.3.3 which is incompatible.
# distributed 2022.2.0 requires cloudpickle>=1.5.0, but you have cloudpickle 1.3.0 which is incompatible.
# cmdstanpy 1.0.4 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
# Successfully installed DataProperty-0.55.0 DyNet-2.1.2 GitPython-3.1.27 absl-py-0.15.0 aiohttp-cors-0.7.0 aioredis-2.0.1 anyio-3.6.1 bcrypt-3.2.2 blessings-1.7 bleurt-0.0.2 chex-0.1.4 clang-5.0 cloudpickle-1.3.0 colorama-0.4.5 colorful-0.5.4 cryptography-37.0.4 datasets-2.4.0 deprecated-1.2.13 dm-haiku-0.0.5 docker-pycreds-0.4.0 einops-0.3.2 fabric-2.6.0 fastapi-0.79.1 flatbuffers-1.12 ftfy-6.1.1 func-timeout-4.3.5 gast-0.4.0 gitdb-4.0.9 google-cloud-core-1.7.3 google-cloud-storage-1.36.2 google-crc32c-1.3.0 google-resumable-media-1.3.3 gpustat-0.6.0 h11-0.13.0 huggingface-hub-0.8.1 invoke-1.7.1 jax-0.2.28 jmp-0.0.2 jsonlines-2.0.0 keras-2.6.0 lm-dataformat-0.0.20 lm-eval-0.2.0 mbstrdecoder-1.1.1 mock-4.0.3 msgfy-0.2.0 multiprocess-0.70.13 nagisa-0.2.7 numexpr-2.7.2 numpy-1.19.5 nvidia-ml-py3-7.352.0 openai-0.6.4 opencensus-0.11.0 opencensus-context-0.1.3 optax-0.0.9 paramiko-2.11.0 pathlib2-2.3.7.post1 pathtools-0.1.2 pathvalidate-2.5.2 portalocker-2.5.1 prometheus-client-0.14.1 py-spy-0.3.12 pybind11-2.6.2 pycountry-20.7.3 pynacl-1.5.0 pytablewriter-0.58.0 ray-1.4.1 redis-4.3.4 requests-2.25.1 responses-0.18.0 rouge-score-0.0.4 sacrebleu-1.5.0 sentencepiece-0.1.97 sentry-sdk-1.9.5 setproctitle-1.3.2 shortuuid-1.0.9 smmap-5.0.0 sniffio-1.2.0 sqlitedict-1.6.0 starlette-0.19.1 tabledata-1.3.0 tcolorpy-0.1.2 tensorboard-2.6.0 tensorflow-2.6.5+zzzcolab20220523104206 tensorflow-cpu-2.6.5 tensorflow-estimator-2.6.0 tf-slim-1.1.0 tokenizers-0.12.1 tqdm-multiprocess-0.0.11 transformers-4.21.1 typepy-1.3.0 typing-extensions-3.10.0.2 urllib3-1.26.12 uvicorn-0.18.2 wandb-0.13.2 wrapt-1.12.1 xxhash-3.0.0 zstandard-0.15.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./mesh-transformer-jax
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting jax==0.2.12
#   Downloading jax-0.2.12.tar.gz (590 kB)
#      |████████████████████████████████| 590 kB 5.1 MB/s
# Collecting tensorflow==2.5.0
#   Downloading tensorflow-2.5.0-cp37-cp37m-manylinux2010_x86_64.whl (454.3 MB)
#      |████████████████████████████████| 454.3 MB 12 kB/s
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.7/dist-packages (from jax==0.2.12) (1.19.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from jax==0.2.12) (0.15.0)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.7/dist-packages (from jax==0.2.12) (3.3.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.15.0)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (2.6.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (3.17.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (0.37.1)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 37.6 MB/s
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (0.4.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (3.1.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (0.2.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.12)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.12.1)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.6.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.1.0)
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp37-cp37m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 38.9 MB/s
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 46.1 MB/s
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow==2.5.0) (1.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.25.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2022.6.15)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (1.26.12)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (3.2.0)
# Building wheels for collected packages: mesh-transformer, jax
#   Building wheel for mesh-transformer (setup.py) ... done
#   Created wheel for mesh-transformer: filename=mesh_transformer-0.0.0-py3-none-any.whl size=26330 sha256=f8faaed1e78e20306d4fdc4fde27e85ebb41e8aee5c426721d321353e33d8a35
#   Stored in directory: /root/.cache/pip/wheels/56/bd/89/b1f6b2f3d6b938d0c5812ee97756a1afd32521bea293543863
#   Building wheel for jax (setup.py) ... done
#   Created wheel for jax: filename=jax-0.2.12-py3-none-any.whl size=682487 sha256=d4d059a1efd6f15dd721fec3a86cc92554e92d41233c49f575b985a85d4f307d
#   Stored in directory: /root/.cache/pip/wheels/f6/4d/e5/73eec5070b77f25664c67bd793d4eb97f41bbf9be7afafd15e
# Successfully built mesh-transformer jax
# Installing collected packages: typing-extensions, grpcio, tensorflow-estimator, keras-nightly, tensorflow, mesh-transformer, jax
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.47.0
#     Uninstalling grpcio-1.47.0:
#       Successfully uninstalled grpcio-1.47.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.6.5+zzzcolab20220523104206
#     Uninstalling tensorflow-2.6.5+zzzcolab20220523104206:
#       Successfully uninstalled tensorflow-2.6.5+zzzcolab20220523104206
#   Attempting uninstall: jax
#     Found existing installation: jax 0.2.28
#     Uninstalling jax-0.2.28:
#       Successfully uninstalled jax-0.2.28
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
# tensorflow-cpu 2.6.5 requires grpcio<2.0,>=1.37.0, but you have grpcio 1.34.1 which is incompatible.
# tensorflow-cpu 2.6.5 requires tensorflow-estimator<2.7,>=2.6.0, but you have tensorflow-estimator 2.5.0 which is incompatible.
# starlette 0.19.1 requires typing-extensions>=3.10.0; python_version < "3.10", but you have typing-extensions 3.7.4.3 which is incompatible.
# Successfully installed grpcio-1.34.1 jax-0.2.12 keras-nightly-2.5.0.dev2021032900 mesh-transformer-0.0.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 typing-extensions-3.7.4.3

# %%
# !pip install -U jaxlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.7/dist-packages (0.3.15)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from jaxlib) (0.15.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.7/dist-packages (from jaxlib) (1.19.5)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.7/dist-packages (from jaxlib) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py->jaxlib) (1.15.0)

# %% [markdown]
# ## Setup Model

# %%
import os
import requests 
from jax.config import config

colab_tpu_addr = os.environ['COLAB_TPU_ADDR'].split(':')[0]
url = f'http://{colab_tpu_addr}:8475/requestversion/tpu_driver0.1_dev20210607'
requests.post(url)

# The following is required to use TPU Driver as JAX's backend.
config.FLAGS.jax_xla_backend = "tpu_driver"
config.FLAGS.jax_backend_target = "grpc://" + os.environ['COLAB_TPU_ADDR']

# %% [markdown]
# Sometimes the next step errors for some reason, just run it again ¯\\\_(ツ)\_/¯

# %%
import time

import jax
from jax.experimental import maps
import numpy as np
import optax
import transformers

from mesh_transformer.checkpoint import read_ckpt_lowmem
from mesh_transformer.sampling import nucleaus_sample
from mesh_transformer.transformer_shard import CausalTransformer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-a22d9a83aa66> in <module>
#       1 import time
#       2
# ----> 3 import jax
#       4 from jax.experimental import maps
#       5 import numpy as np
#
# /usr/local/lib/python3.7/dist-packages/jax/__init__.py in <module>
#      96   xla_computation,
#      97 )
# ---> 98 from .experimental.maps import soft_pmap
#      99 from .version import __version__
#     100
#
# /usr/local/lib/python3.7/dist-packages/jax/experimental/maps.py in <module>
#      23 from functools import wraps, partial
#      24
# ---> 25 from .. import numpy as jnp
#      26 from .. import core
#      27 from .. import linear_util as lu
#
# /usr/local/lib/python3.7/dist-packages/jax/numpy/__init__.py in <module>
#      14
#      15 # flake8: noqa: F401
# ---> 16 from . import fft
#      17 from . import linalg
#      18
#
# /usr/local/lib/python3.7/dist-packages/jax/numpy/fft.py in <module>
#      15 # flake8: noqa: F401
#      16
# ---> 17 from jax._src.numpy.fft import (
#      18   ifft,
#      19   ifft2,
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/fft.py in <module>
#      16 import numpy as np
#      17
# ---> 18 from jax import lax
#      19 from jax.lib import xla_client
#      20 from .util import _wraps
#
# /usr/local/lib/python3.7/dist-packages/jax/lax/__init__.py in <module>
#     326   while_p,
#     327 )
# --> 328 from jax._src.lax.fft import (
#     329   fft,
#     330   fft_p,
#
# /usr/local/lib/python3.7/dist-packages/jax/_src/lax/fft.py in <module>
#     141 batching.primitive_batchers[fft_p] = fft_batching_rule
#     142 if pocketfft:
# --> 143   xla.backend_specific_translations['cpu'][fft_p] = pocketfft.pocketfft
#
# AttributeError: module 'jaxlib.pocketfft' has no attribute 'pocketfft'

# %%
params = {
  "layers": 28,
  "d_model": 4096,
  "n_heads": 16,
  "n_vocab": 50400,
  "norm": "layernorm",
  "pe": "rotary",
  "pe_rotary_dims": 64,

  "seq": 2048,
  "cores_per_replica": 8,
  "per_replica_batch": 1,
}

per_replica_batch = params["per_replica_batch"]
cores_per_replica = params["cores_per_replica"]
seq = params["seq"]


params["sampler"] = nucleaus_sample

# here we "remove" the optimizer parameters from the model (as we don't need them for inference)
params["optimizer"] = optax.scale(0)

mesh_shape = (jax.device_count() // cores_per_replica, cores_per_replica)
devices = np.array(jax.devices()).reshape(mesh_shape)

maps.thread_resources.env = maps.ResourceEnv(maps.Mesh(devices, ('dp', 'mp')))

tokenizer = transformers.GPT2TokenizerFast.from_pretrained('gpt2')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1042301.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1355256.0, style=ProgressStyle(descript…

# %% [markdown]
# Here we create the network and load the parameters from the downloaded files. Expect this to take around 5 minutes.

# %%
total_batch = per_replica_batch * jax.device_count() // cores_per_replica

network = CausalTransformer(params)

network.state = read_ckpt_lowmem(network.state, "step_383500/", devices.shape[1])

network.state = network.move_xmap(network.state, np.zeros(cores_per_replica))
# Out:
# /usr/local/lib/python3.7/dist-packages/jax/experimental/maps.py:412: UserWarning: xmap is an experimental feature and probably has bugs!
#   warn("xmap is an experimental feature and probably has bugs!")
# key shape (8, 2)
# in shape (1, 2048)
# dp 1
# mp 8
# read from gcs in 22.633s

# %% [markdown]
# ## Run Model
#
# Finally, we are ready to infer with the model! The first sample takes around a minute due to compilation, but after that it should only take about 10 seconds per sample.
#
# Feel free to mess with the different sampling parameters (top_p and temp), as well as the length of the generations (gen_len, causes a recompile when changed).
#
# You can also change other things like per_replica_batch in the previous cells to change how many generations are done in parallel. A larger batch has higher latency but higher throughput when measured in tokens generated/s. This is useful for doing things like best-of-n cherry picking.
#
# *Tip for best results: Make sure your prompt does not have any trailing spaces, which tend to confuse the model due to the BPE tokenization used during training.*

# %%
# allow text wrapping in generated output: https://stackoverflow.com/a/61401455
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
def infer(context, top_p=0.9, temp=1.0, gen_len=512):
    tokens = tokenizer.encode(context)

    provided_ctx = len(tokens)
    pad_amount = seq - provided_ctx

    padded_tokens = np.pad(tokens, ((pad_amount, 0),)).astype(np.uint32)
    batched_tokens = np.array([padded_tokens] * total_batch)
    length = np.ones(total_batch, dtype=np.uint32) * len(tokens)

    start = time.time()
    output = network.generate(batched_tokens, length, gen_len, {"top_p": np.ones(total_batch) * top_p, "temp": np.ones(total_batch) * temp})

    samples = []
    decoded_tokens = output[1][0]

    for o in decoded_tokens[:, :, 0]:
      samples.append(f"\033[1m{context}\033[0m{tokenizer.decode(o)}")

    print(f"completion done in {time.time() - start:06}s")
    return samples

print(infer("EleutherAI is")[0])
# Out:
# completion done in 59.615925312042236s
#  a team of senior and junior developers that are working together to push back the frontiers of racing videogames. The team is involved in developing a racing videogame from the ground up. It will feature cars and tracks drawn from a creative process.
#
# ELEUTERAI TEAM
#
# HISTORY
#
# Founded by Gianfrancesco Cengia, EleuterAI is an independent videogame development team that started making videogames in 2004.
#
# A young team formed in collaboration between the principle members Gianfrancesco Cengia and Luigi Zampar (as well as Luca Barbero, Rolando Labernini and Simone Trovato). Over a period of five years, the members learned how to write code, how to build efficient software processes and how to design a fun racing game. All the while, they shared an enthusiasm for racing games and the ever-evolving technology that became a shared passion.
#
# After five years of collaboration, the team reached the starting point of its car games. Due to the great success of Formula One 2017, the videogame race team found the confidence to start a new phase of their adventure.
#
# The innovative approach of the team also brought results to the printed world. Indeed, the videogames that the EleuterAI team published in 2014, 2015 and 2016 are among the highest-selling videogames on the French market.
#
# Among the videogame developments produced by the team, Trovato mentions Firepower, Vinicius and Stop and Stares.
#
# The EleuterAI experience also showed the team the opportunity to expand its horizons outside of car racing. Indeed, as of today, the group is involved in developing a videogame based on the legendary Italian car brand Alfa Romeo. The development phase is already underway and will be a challenge and new experience for the team. The project is planned to be released in late 2019.
#
# CHALLENGE
#
# This project will be for the EleuterAI team an extraordinary opportunity to show their capabilities and the expertise acquired in the car race gaming experience. As a result, we could have a videogame of the highest quality.
#
# Team-work and collaboration will be key elements to develop a fun racing experience and will be at the center of the game.
#
# Vision & Values
#
# We are close to our mission, which is to make the best racing videogames. We don’t have any brand vision or values, but we do have a very clear idea of

# %%
#@title  { form-width: "300px" }
top_p = 0.4 #@param {type:"slider", min:0, max:1, step:0.1}
temp = 1 #@param {type:"slider", min:0, max:1, step:0.1}

context = """In a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the Andes Mountains. Even more surprising to the researchers was the fact that the unicorns spoke perfect English."""

print(infer(top_p=top_p, temp=temp, gen_len=512, context=context)[0])
# Out:
# completion done in 13.510299682617188s
#  The scientists decided to ask one of the creatures to show them what English sounds like.
#
# The creature was then transported in a private jet to a real-life, windy city, where it was finally placed on the roof of a building, wearing a set of headphones. The scientist proceeded to ask the creature to demonstrate the letter “R”, which turned out to be an “R”-shaped unicorn.
#
# At this point, the scientists expected the creature to start singing, or making a horselike sound. Instead, the unicorn imitated a car horn, roaring “Raaaaaarrrr!”. The scientist chuckled at the unplanned execution. The unicorn finished the demonstration by shouting “Ahhhhhhhhhhhhhhhhh!”, sounding like an escaped convict having an orgasm.
#
# Then the creature, after spending about an hour on the rooftop, as it was exhausted, went to sleep. By chance, the creature’s body was mown down by a steamroller a few hours later, and its body was sent to the scientists.
#
# The scientists analysed the DNA and created a synthetic version of the creature’s horn, and inserted it into a New Zealand sheep. The sheep were taught to use a computer program for spelling, but after the sheep had been taught to pronounce the letter “R”, it would never stop saying it.
#
# Dr. Graeme Lloyd, of the University of Canterbury, New Zealand, said “We created this synthetic horn by the end of the project, and inserted it into the New Zealand sheep. We told the sheep that they had to use the synthetic horn to say “R”, and that they must never say anything else. For a month, the sheep would wake up at dawn, go on to the roof of our office building, and then try to say “R”. In a few weeks, the sheep’s heads would fall off.”
#
# Related
#
# Comments
#
# Before going off to sally forth about the wonders and dangers of the internet, did you perhaps check on BING to see if your best friend had posted up something about you?
# Or, perhaps it’s more likely that you’re living in a fantasy land, which, when looking at that headline, is probably the case.
#
# Actually, that article about unicorns is so unbelievably stupid and self-satifyingly absurd, even I had to
